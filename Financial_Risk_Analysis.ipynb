# %%
#import standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import opendatasets as od
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
data=pd.read_csv('financial_risk_assessment.csv')
data.head()
# Out:
#    Age      Gender Education Level Marital Status   Income  Credit Score  \
# 0   49        Male             PhD       Divorced  72799.0         688.0
# 1   57      Female      Bachelor's        Widowed      NaN         690.0
# 2   21  Non-binary        Master's         Single  55687.0         600.0
# 3   59        Male      Bachelor's         Single  26508.0         622.0
# 4   25  Non-binary      Bachelor's        Widowed  49427.0         766.0
#
#    Loan Amount Loan Purpose Employment Status  Years at Current Job  \
# 0      45713.0     Business        Unemployed                    19
# 1      33835.0         Auto          Employed                     6
# 2      36623.0         Home          Employed                     8
# 3      26541.0     Personal        Unemployed                     2
# 4      36528.0     Personal        Unemployed                    10
#
#   Payment History  Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# 0            Poor              0.154313      120228.0                   0.0
# 1            Fair              0.148920       55849.0                   0.0
# 2            Fair              0.362398      180700.0                   3.0
# 3       Excellent              0.454964      157319.0                   3.0
# 4            Fair              0.143242      287140.0                   NaN
#
#               City State       Country  Previous Defaults  \
# 0   Port Elizabeth    AS        Cyprus                2.0
# 1  North Catherine    OH  Turkmenistan                3.0
# 2      South Scott    OK    Luxembourg                3.0
# 3       Robinhaven    PR        Uganda                4.0
# 4      New Heather    IL       Namibia                3.0
#
#    Marital Status Change Risk Rating
# 0                      2         Low
# 1                      2      Medium
# 2                      2      Medium
# 3                      2      Medium
# 4                      1         Low

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    15000 non-null  int64
#  1   Gender                 15000 non-null  object
#  2   Education Level        15000 non-null  object
#  3   Marital Status         15000 non-null  object
#  4   Income                 12750 non-null  float64
#  5   Credit Score           12750 non-null  float64
#  6   Loan Amount            12750 non-null  float64
#  7   Loan Purpose           15000 non-null  object
#  8   Employment Status      15000 non-null  object
#  9   Years at Current Job   15000 non-null  int64
#  10  Payment History        15000 non-null  object
#  11  Debt-to-Income Ratio   15000 non-null  float64
#  12  Assets Value           12750 non-null  float64
#  13  Number of Dependents   12750 non-null  float64
#  14  City                   15000 non-null  object
#  15  State                  15000 non-null  object
#  16  Country                15000 non-null  object
#  17  Previous Defaults      12750 non-null  float64
#  18  Marital Status Change  15000 non-null  int64
#  19  Risk Rating            15000 non-null  object
# dtypes: float64(7), int64(3), object(10)
# memory usage: 2.3+ MB

# %%
data.shape
# Out:
# (15000, 20)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Marital Status', 'Income',
#        'Credit Score', 'Loan Amount', 'Loan Purpose', 'Employment Status',
#        'Years at Current Job', 'Payment History', 'Debt-to-Income Ratio',
#        'Assets Value', 'Number of Dependents', 'City', 'State', 'Country',
#        'Previous Defaults', 'Marital Status Change', 'Risk Rating'],
#       dtype='object')

# %%
data.describe().style.background_gradient(cmap='Pastel2_r')
# Out:
# <style  type="text/css" >
# #T_9e517_row0_col0,#T_9e517_row0_col2,#T_9e517_row0_col4,#T_9e517_row0_col5,#T_9e517_row0_col7,#T_9e517_row0_col8,#T_9e517_row0_col9,#T_9e517_row7_col1,#T_9e517_row7_col3,#T_9e517_row7_col6{
#             background-color:  #b3e2cd;
#             color:  #000000;
#         }#T_9e517_row0_col1,#T_9e517_row0_col6,#T_9e517_row1_col0,#T_9e517_row1_col2,#T_9e517_row1_col4,#T_9e517_row1_col5,#T_9e517_row1_col7,#T_9e517_row1_col8,#T_9e517_row1_col9,#T_9e517_row2_col0,#T_9e517_row2_col2,#T_9e517_row2_col4,#T_9e517_row2_col5,#T_9e517_row2_col7,#T_9e517_row2_col8,#T_9e517_row2_col9,#T_9e517_row3_col0,#T_9e517_row3_col1,#T_9e517_row3_col2,#T_9e517_row3_col3,#T_9e517_row3_col4,#T_9e517_row3_col5,#T_9e517_row3_col6,#T_9e517_row3_col7,#T_9e517_row3_col8,#T_9e517_row3_col9,#T_9e517_row4_col0,#T_9e517_row4_col2,#T_9e517_row4_col4,#T_9e517_row4_col5,#T_9e517_row4_col7,#T_9e517_row4_col8,#T_9e517_row4_col9,#T_9e517_row5_col0,#T_9e517_row5_col2,#T_9e517_row5_col4,#T_9e517_row5_col5,#T_9e517_row5_col7,#T_9e517_row5_col8,#T_9e517_row5_col9,#T_9e517_row6_col0,#T_9e517_row6_col2,#T_9e517_row6_col4,#T_9e517_row6_col5,#T_9e517_row6_col7,#T_9e517_row6_col8,#T_9e517_row6_col9,#T_9e517_row7_col0,#T_9e517_row7_col2,#T_9e517_row7_col4,#T_9e517_row7_col5,#T_9e517_row7_col7,#T_9e517_row7_col8,#T_9e517_row7_col9{
#             background-color:  #cccccc;
#             color:  #000000;
#         }#T_9e517_row0_col3,#T_9e517_row2_col1,#T_9e517_row2_col3,#T_9e517_row2_col6{
#             background-color:  #f1e2cc;
#             color:  #000000;
#         }#T_9e517_row1_col1,#T_9e517_row1_col6,#T_9e517_row5_col1,#T_9e517_row5_col3,#T_9e517_row5_col6{
#             background-color:  #f4cae4;
#             color:  #000000;
#         }#T_9e517_row1_col3{
#             background-color:  #e6f5c9;
#             color:  #000000;
#         }#T_9e517_row4_col1,#T_9e517_row4_col3,#T_9e517_row4_col6{
#             background-color:  #fff2ae;
#             color:  #000000;
#         }#T_9e517_row6_col1,#T_9e517_row6_col6{
#             background-color:  #fdcdac;
#             color:  #000000;
#         }#T_9e517_row6_col3{
#             background-color:  #cbd5e8;
#             color:  #000000;
#         }</style><table id="T_9e517_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Income</th>        <th class="col_heading level0 col2" >Credit Score</th>        <th class="col_heading level0 col3" >Loan Amount</th>        <th class="col_heading level0 col4" >Years at Current Job</th>        <th class="col_heading level0 col5" >Debt-to-Income Ratio</th>        <th class="col_heading level0 col6" >Assets Value</th>        <th class="col_heading level0 col7" >Number of Dependents</th>        <th class="col_heading level0 col8" >Previous Defaults</th>        <th class="col_heading level0 col9" >Marital Status Change</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e517_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_9e517_row0_col0" class="data row0 col0" >15000.000000</td>
#                         <td id="T_9e517_row0_col1" class="data row0 col1" >12750.000000</td>
#                         <td id="T_9e517_row0_col2" class="data row0 col2" >12750.000000</td>
#                         <td id="T_9e517_row0_col3" class="data row0 col3" >12750.000000</td>
#                         <td id="T_9e517_row0_col4" class="data row0 col4" >15000.000000</td>
#                         <td id="T_9e517_row0_col5" class="data row0 col5" >15000.000000</td>
#                         <td id="T_9e517_row0_col6" class="data row0 col6" >12750.000000</td>
#                         <td id="T_9e517_row0_col7" class="data row0 col7" >12750.000000</td>
#                         <td id="T_9e517_row0_col8" class="data row0 col8" >12750.000000</td>
#                         <td id="T_9e517_row0_col9" class="data row0 col9" >15000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e517_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_9e517_row1_col0" class="data row1 col0" >43.452667</td>
#                         <td id="T_9e517_row1_col1" class="data row1 col1" >69933.398510</td>
#                         <td id="T_9e517_row1_col2" class="data row1 col2" >699.109098</td>
#                         <td id="T_9e517_row1_col3" class="data row1 col3" >27450.010902</td>
#                         <td id="T_9e517_row1_col4" class="data row1 col4" >9.476267</td>
#                         <td id="T_9e517_row1_col5" class="data row1 col5" >0.350438</td>
#                         <td id="T_9e517_row1_col6" class="data row1 col6" >159741.497176</td>
#                         <td id="T_9e517_row1_col7" class="data row1 col7" >2.026510</td>
#                         <td id="T_9e517_row1_col8" class="data row1 col8" >1.992471</td>
#                         <td id="T_9e517_row1_col9" class="data row1 col9" >0.998467</td>
#             </tr>
#             <tr>
#                         <th id="T_9e517_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_9e517_row2_col0" class="data row2 col0" >14.910732</td>
#                         <td id="T_9e517_row2_col1" class="data row2 col1" >29163.626207</td>
#                         <td id="T_9e517_row2_col2" class="data row2 col2" >57.229465</td>
#                         <td id="T_9e517_row2_col3" class="data row2 col3" >12949.940135</td>
#                         <td id="T_9e517_row2_col4" class="data row2 col4" >5.769707</td>
#                         <td id="T_9e517_row2_col5" class="data row2 col5" >0.143919</td>
#                         <td id="T_9e517_row2_col6" class="data row2 col6" >80298.115832</td>
#                         <td id="T_9e517_row2_col7" class="data row2 col7" >1.411300</td>
#                         <td id="T_9e517_row2_col8" class="data row2 col8" >1.416909</td>
#                         <td id="T_9e517_row2_col9" class="data row2 col9" >0.813782</td>
#             </tr>
#             <tr>
#                         <th id="T_9e517_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_9e517_row3_col0" class="data row3 col0" >18.000000</td>
#                         <td id="T_9e517_row3_col1" class="data row3 col1" >20005.000000</td>
#                         <td id="T_9e517_row3_col2" class="data row3 col2" >600.000000</td>
#                         <td id="T_9e517_row3_col3" class="data row3 col3" >5000.000000</td>
#                         <td id="T_9e517_row3_col4" class="data row3 col4" >0.000000</td>
#                         <td id="T_9e517_row3_col5" class="data row3 col5" >0.100004</td>
#                         <td id="T_9e517_row3_col6" class="data row3 col6" >20055.000000</td>
#                         <td id="T_9e517_row3_col7" class="data row3 col7" >0.000000</td>
#                         <td id="T_9e517_row3_col8" class="data row3 col8" >0.000000</td>
#                         <td id="T_9e517_row3_col9" class="data row3 col9" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e517_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_9e517_row4_col0" class="data row4 col0" >31.000000</td>
#                         <td id="T_9e517_row4_col1" class="data row4 col1" >44281.500000</td>
#                         <td id="T_9e517_row4_col2" class="data row4 col2" >650.000000</td>
#                         <td id="T_9e517_row4_col3" class="data row4 col3" >16352.500000</td>
#                         <td id="T_9e517_row4_col4" class="data row4 col4" >4.000000</td>
#                         <td id="T_9e517_row4_col5" class="data row4 col5" >0.227386</td>
#                         <td id="T_9e517_row4_col6" class="data row4 col6" >90635.250000</td>
#                         <td id="T_9e517_row4_col7" class="data row4 col7" >1.000000</td>
#                         <td id="T_9e517_row4_col8" class="dat

# %%
data.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Education Level             0
# Marital Status              0
# Income                   2250
# Credit Score             2250
# Loan Amount              2250
# Loan Purpose                0
# Employment Status           0
# Years at Current Job        0
# Payment History             0
# Debt-to-Income Ratio        0
# Assets Value             2250
# Number of Dependents     2250
# City                        0
# State                       0
# Country                     0
# Previous Defaults        2250
# Marital Status Change       0
# Risk Rating                 0
# dtype: int64

# %%
# Remove the null values
data=data.dropna()
data.shape
# Out:
# (5716, 20)

# %%
#duplicate values
duplicates=data.duplicated().sum()
print(f'The data set contains {duplicates} values')
# Out:
# The data set contains 0 values

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['Age'],color='red')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#Gender Percentage
plt.figure(figsize=(10,5))
data['Gender'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',
     explode=[0,0,0.1],
    labels=['Female','Non-binary','Male'],
    colors=['#ffb703','#c1121f','#ff99c8'],
    autopct='%1.2f%%',
    shadow=True)
plt.title('Gender distribution in the data')
plt.show()

# %%
# Visisualize the Education level in the data
data['Education Level'].value_counts().sort_values(ascending=False)\
.plot(kind='bar',figsize=(10,5),color=['#ffd60a','#84a59d','#f15bb5','#7209b7'])
plt.xlabel('Education Level')
plt.ylabel('Count of values')
plt.show()

# %%
#To visiualize the in each gender with differnet marital status
plt.figure(figsize=(10,5))
sns.histplot(data=data,x='Gender',hue='Marital Status',multiple="dodge", shrink=.8)
plt.xlabel('Gender')
plt.ylabel('Count of values')
plt.show()

# %%
# let's find the realtion beteen aga and income with loan purpose 
plt.figure(figsize=(10,5))
sns.relplot(x ="Age", y ="Income", data = data[:500],hue='Loan Purpose')
plt.title('The relation between Age and income with loan purpose')
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
# Visualize the h
employe=pd.DataFrame(data.groupby('Gender')['Employment Status'].value_counts())
employe.unstack().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_893ee_row0_col0{
#             background-color:  #d82422;
#             color:  #f1f1f1;
#         }#T_893ee_row0_col1,#T_893ee_row0_col2,#T_893ee_row2_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_893ee_row1_col0,#T_893ee_row1_col1,#T_893ee_row1_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_893ee_row2_col1{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_893ee_row2_col2{
#             background-color:  #bd151a;
#             color:  #f1f1f1;
#         }</style><table id="T_893ee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="3">Employment Status</th>    </tr>    <tr>        <th class="index_name level1" >Employment Status</th>        <th class="col_heading level1 col0" >Employed</th>        <th class="col_heading level1 col1" >Self-employed</th>        <th class="col_heading level1 col2" >Unemployed</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_893ee_level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_893ee_row0_col0" class="data row0 col0" >639</td>
#                         <td id="T_893ee_row0_col1" class="data row0 col1" >666</td>
#                         <td id="T_893ee_row0_col2" class="data row0 col2" >643</td>
#             </tr>
#             <tr>
#                         <th id="T_893ee_level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_893ee_row1_col0" class="data row1 col0" >627</td>
#                         <td id="T_893ee_row1_col1" class="data row1 col1" >611</td>
#                         <td id="T_893ee_row1_col2" class="data row1 col2" >614</td>
#             </tr>
#             <tr>
#                         <th id="T_893ee_level0_row2" class="row_heading level0 row2" >Non-binary</th>
#                         <td id="T_893ee_row2_col0" class="data row2 col0" >644</td>
#                         <td id="T_893ee_row2_col1" class="data row2 col1" >635</td>
#                         <td id="T_893ee_row2_col2" class="data row2 col2" >637</td>
#             </tr>
#     </tbody></table>

# %%
# How many people from each country 
data['Country'].value_counts().sort_values(ascending=False).head(50)\
.plot(kind='bar',figsize=(10,5),color='green')
plt.xlabel('Country')
plt.ylabel('Count of values')
plt.title('How many people in each Country')
plt.show()

# %%
# Find the average credit score in each category
aver_credit_score=pd.DataFrame(data.groupby('Gender')['Credit Score'].mean().sort_values(ascending=False))
aver_credit_score.style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_7a556_row0_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_7a556_row1_col0{
#             background-color:  #00aaaa;
#             color:  #000000;
#         }#T_7a556_row2_col0{
#             background-color:  #00ff80;
#             color:  #000000;
#         }</style><table id="T_7a556_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Credit Score</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a556_level0_row0" class="row_heading level0 row0" >Non-binary</th>
#                         <td id="T_7a556_row0_col0" class="data row0 col0" >700.377349</td>
#             </tr>
#             <tr>
#                         <th id="T_7a556_level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_7a556_row1_col0" class="data row1 col0" >698.884989</td>
#             </tr>
#             <tr>
#                         <th id="T_7a556_level0_row2" class="row_heading level0 row2" >Female</th>
#                         <td id="T_7a556_row2_col0" class="data row2 col0" >698.130390</td>
#             </tr>
#     </tbody></table>

# %%
gender_loan=pd.DataFrame(data.groupby('Gender')['Loan Purpose'].value_counts())
gender_loan.plot(kind='bar',figsize=(10,5),color=['red'])
plt.title('Gender and loan purpose bar chart')
plt.xlabel('Gener and loan purpose')
plt.ylabel('Count of values')
plt.show()

# %%
data.head(1)
# Out:
#    Age Gender Education Level Marital Status   Income  Credit Score  \
# 0   49   Male             PhD       Divorced  72799.0         688.0
#
#    Loan Amount Loan Purpose Employment Status  Years at Current Job  \
# 0      45713.0     Business        Unemployed                    19
#
#   Payment History  Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# 0            Poor              0.154313      120228.0                   0.0
#
#              City State Country  Previous Defaults  Marital Status Change  \
# 0  Port Elizabeth    AS  Cyprus                2.0                      2
#
#   Risk Rating
# 0         Low

# %%
Education_exp=pd.DataFrame(data.groupby('Education Level')['Years at Current Job'].value_counts().sort_values(ascending=False))
Education_exp.unstack().style.background_gradient(cmap='copper_r')
# Out:
# <style  type="text/css" >
# #T_0d24c_row0_col0,#T_0d24c_row0_col4,#T_0d24c_row0_col5,#T_0d24c_row0_col6,#T_0d24c_row0_col16,#T_0d24c_row1_col2,#T_0d24c_row1_col6,#T_0d24c_row1_col7,#T_0d24c_row1_col9,#T_0d24c_row1_col10,#T_0d24c_row1_col12,#T_0d24c_row1_col13,#T_0d24c_row1_col17,#T_0d24c_row1_col19,#T_0d24c_row2_col1,#T_0d24c_row2_col3,#T_0d24c_row2_col15,#T_0d24c_row2_col18,#T_0d24c_row3_col8,#T_0d24c_row3_col11,#T_0d24c_row3_col14{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_0d24c_row0_col1,#T_0d24c_row3_col17{
#             background-color:  #af6f47;
#             color:  #000000;
#         }#T_0d24c_row0_col2{
#             background-color:  #ad6d46;
#             color:  #000000;
#         }#T_0d24c_row0_col3{
#             background-color:  #d28555;
#             color:  #000000;
#         }#T_0d24c_row0_col7{
#             background-color:  #b27048;
#             color:  #000000;
#         }#T_0d24c_row0_col8{
#             background-color:  #8f5b3a;
#             color:  #f1f1f1;
#         }#T_0d24c_row0_col9,#T_0d24c_row0_col11,#T_0d24c_row1_col3,#T_0d24c_row1_col4,#T_0d24c_row1_col5,#T_0d24c_row1_col8,#T_0d24c_row1_col14,#T_0d24c_row1_col16,#T_0d24c_row2_col2,#T_0d24c_row2_col6,#T_0d24c_row2_col7,#T_0d24c_row2_col12,#T_0d24c_row2_col17,#T_0d24c_row2_col19,#T_0d24c_row3_col0,#T_0d24c_row3_col1,#T_0d24c_row3_col6,#T_0d24c_row3_col10,#T_0d24c_row3_col13,#T_0d24c_row3_col15,#T_0d24c_row3_col18{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_0d24c_row0_col10,#T_0d24c_row2_col5{
#             background-color:  #b8744a;
#             color:  #000000;
#         }#T_0d24c_row0_col12,#T_0d24c_row0_col15,#T_0d24c_row1_col15{
#             background-color:  #cc8152;
#             color:  #000000;
#         }#T_0d24c_row0_col13,#T_0d24c_row2_col13{
#             background-color:  #452c1c;
#             color:  #f1f1f1;
#         }#T_0d24c_row0_col14,#T_0d24c_row2_col14{
#             background-color:  #1f140c;
#             color:  #f1f1f1;
#         }#T_0d24c_row0_col17{
#             background-color:  #8c5838;
#             color:  #f1f1f1;
#         }#T_0d24c_row0_col18,#T_0d24c_row3_col16{
#             background-color:  #5a3924;
#             color:  #f1f1f1;
#         }#T_0d24c_row0_col19{
#             background-color:  #ffae6f;
#             color:  #000000;
#         }#T_0d24c_row1_col0{
#             background-color:  #cd8253;
#             color:  #000000;
#         }#T_0d24c_row1_col1{
#             background-color:  #f69b63;
#             color:  #000000;
#         }#T_0d24c_row1_col11{
#             background-color:  #ffac6d;
#             color:  #000000;
#         }#T_0d24c_row1_col18{
#             background-color:  #c37b4f;
#             color:  #000000;
#         }#T_0d24c_row2_col0{
#             background-color:  #5e3b26;
#             color:  #f1f1f1;
#         }#T_0d24c_row2_col4{
#             background-color:  #d78857;
#             color:  #000000;
#         }#T_0d24c_row2_col8{
#             background-color:  #ac6d45;
#             color:  #000000;
#         }#T_0d24c_row2_col9{
#             background-color:  #8e5a39;
#             color:  #f1f1f1;
#         }#T_0d24c_row2_col10,#T_0d24c_row3_col5{
#             background-color:  #ec955f;
#             color:  #000000;
#         }#T_0d24c_row2_col11{
#             background-color:  #a36742;
#             color:  #000000;
#         }#T_0d24c_row2_col16{
#             background-color:  #e18e5b;
#             color:  #000000;
#         }#T_0d24c_row3_col2{
#             background-color:  #ffaa6c;
#             color:  #000000;
#         }#T_0d24c_row3_col3{
#             background-color:  #342115;
#             color:  #f1f1f1;
#         }#T_0d24c_row3_col4{
#             background-color:  #ffad6e;
#             color:  #000000;
#         }#T_0d24c_row3_col7{
#             background-color:  #6e462c;
#             color:  #f1f1f1;
#         }#T_0d24c_row3_col9{
#             background-color:  #7e5033;
#             color:  #f1f1f1;
#         }#T_0d24c_row3_col12{
#             background-color:  #825234;
#             color:  #f1f1f1;
#         }#T_0d24c_row3_col19{
#             background-color:  #754a2f;
#             color:  #f1f1f1;
#         }</style><table id="T_0d24c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="20">Years at Current Job</th>    </tr>    <tr>        <th class="index_name level1" >Years at Current Job</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >2</th>        <th class="col_heading level1 col3" >3</th>        <th class="col_heading level1 col4" >4</th>        <th class="col_heading level1 col5" >5</th>        <th class="col_heading level1 col6" >6</th>        <th class="col_heading level1 col7" >7</th>        <th class="col_heading level1 col8" >8</th>        <th class="col_heading level1 col9" >9</th>        <th class="col_heading level1 col10" >10</th>        <th class="col_heading level1 col11" >11</th>        <th class="col_heading level1 col12" >12</th>        <th class="col_heading level1 col13" >13</th>        <th class="col_heading level1 col14" >14</th>        <th class="col_heading level1 col15" >15</th>        <th class="col_heading level1 col16" >16</th>        <th class="col_heading level1 col17" >17</th>        <th class="col_heading level1 col18" >18</th>        <th class="col_heading level1 col19" >19</th>    </tr>    <tr>        <th class="index_name level0" >Education Level</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d24c_level0_row0" class="row_heading level0 row0" >Bachelor's</th>
#                         <td id="T_0d24c_row0_col0" class="data row0 col0" >82</td>
#                         <td id="T_0d24c_row0_col1" class="data row0 col1" >75</td>
#                         <td id="T_0d24c_row0_col2" class="data row0 col2" >71</td>
#                         <td id="T_0d24c_row0_col3" class="data row0 col3" >75</td>
#                         <td id="T_0d24c_row0_col4" class="data row0 col4" >88</td>
#                         <td id="T_0d24c_row0_col5" class="data row0 col5" >81</td>
#                         <td id="T_0d24c_row0_col6" class="data row0 col6" >74</td>
#                         <td id="T_0d24c_row0_col7" class="data row0 col7" >64</td>
#                         <td id="T_0d24c_row0_col8" class="data row0 col8" >70</td>
#                         <td id="T_0d24c_row0_col9" class="data row0 col9" >63</td>
#                         <td id="T_0d24c_row0_col10" class="data row0 col10" >67</td>
#                         <td id="T_0d24c_row0_col11" class="data row0 col11" >62</td>
#                         <td id="T_0d24c_row0_col12" class="data row0 col12" >66</td>
#                         <td id="T_0d24c_row0_col13" class="data row0 col13" >72</td>
#                         <td id="T_0d24c_row0_col14" class="data row0 col14" >67</td>
#                         <td id="T_0d24c_row0_col15" class="data row0 col15" >72</td>
#                         <td id="T_0d24c_row0_col16" class="data row0 col16" >86</td>
#                         <td id="T_0d24c_row0_col17" class="data row0 col17" >75</td>
#                         <td id="T_0d24c_row0_col18" class="data row0 col18" >79</td>
#                         <td id="T_0d24c_row0_col19" class="data row0 col19" >60</td>
#             </tr>
#             <tr>

# %%
plt.figure(figsize=(10,6))
data['State'].value_counts().sort_values(ascending=False)\
.plot(kind='bar',color=['red'])
plt.title('State distibution')
plt.xlabel('State')
plt.ylabel('Count of values')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.relplot(data=data[:400],x='Income',y='Loan Amount',hue='Risk Rating')
plt.title('Relations between income and loan amount with risk rating')
plt.xlabel('Income')
plt.ylabel('Loan Amount')
plt.show()

# %%
sns.boxplot(data=data, x='Education Level', y='Income')
plt.title('Income by Education Level')
plt.xticks(rotation=45)
plt.show()

# %%
averge_loan_credit_score=pd.DataFrame(data.groupby('Education Level')[['Credit Score','Loan Amount']].mean())
averge_loan_credit_score.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_7b76a_row0_col0{
#             background-color:  #71b1d7;
#             color:  #000000;
#         }#T_7b76a_row0_col1{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_7b76a_row1_col0,#T_7b76a_row1_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_7b76a_row2_col0{
#             background-color:  #72b2d8;
#             color:  #000000;
#         }#T_7b76a_row2_col1{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_7b76a_row3_col0,#T_7b76a_row3_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_7b76a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Credit Score</th>        <th class="col_heading level0 col1" >Loan Amount</th>    </tr>    <tr>        <th class="index_name level0" >Education Level</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b76a_level0_row0" class="row_heading level0 row0" >Bachelor's</th>
#                         <td id="T_7b76a_row0_col0" class="data row0 col0" >699.112491</td>
#                         <td id="T_7b76a_row0_col1" class="data row0 col1" >27466.619048</td>
#             </tr>
#             <tr>
#                         <th id="T_7b76a_level0_row1" class="row_heading level0 row1" >High School</th>
#                         <td id="T_7b76a_row1_col0" class="data row1 col0" >696.977067</td>
#                         <td id="T_7b76a_row1_col1" class="data row1 col1" >27366.248089</td>
#             </tr>
#             <tr>
#                         <th id="T_7b76a_level0_row2" class="row_heading level0 row2" >Master's</th>
#                         <td id="T_7b76a_row2_col0" class="data row2 col0" >699.099296</td>
#                         <td id="T_7b76a_row2_col1" class="data row2 col1" >27729.043662</td>
#             </tr>
#             <tr>
#                         <th id="T_7b76a_level0_row3" class="row_heading level0 row3" >PhD</th>
#                         <td id="T_7b76a_row3_col0" class="data row3 col0" >701.371449</td>
#                         <td id="T_7b76a_row3_col1" class="data row3 col1" >27752.923295</td>
#             </tr>
#     </tbody></table>

# %%
employe_risk=pd.DataFrame(data.groupby(['Employment Status','Risk Rating'])['Gender'].value_counts())
employe_risk.unstack().style.background_gradient(cmap='Reds_r')
# Out:
# <style  type="text/css" >
# #T_22109_row0_col0,#T_22109_row3_col1,#T_22109_row3_col2,#T_22109_row6_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_22109_row0_col1{
#             background-color:  #7c0510;
#             color:  #f1f1f1;
#         }#T_22109_row0_col2{
#             background-color:  #840711;
#             color:  #f1f1f1;
#         }#T_22109_row1_col0{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_22109_row1_col1,#T_22109_row1_col2{
#             background-color:  #fee7dc;
#             color:  #000000;
#         }#T_22109_row2_col0{
#             background-color:  #f24734;
#             color:  #000000;
#         }#T_22109_row2_col1{
#             background-color:  #f85f43;
#             color:  #000000;
#         }#T_22109_row2_col2{
#             background-color:  #f34a36;
#             color:  #000000;
#         }#T_22109_row3_col0{
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }#T_22109_row4_col0,#T_22109_row7_col1{
#             background-color:  #fff4ef;
#             color:  #000000;
#         }#T_22109_row4_col1,#T_22109_row4_col2,#T_22109_row7_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_22109_row5_col0{
#             background-color:  #f5523a;
#             color:  #000000;
#         }#T_22109_row5_col1{
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#         }#T_22109_row5_col2,#T_22109_row8_col1{
#             background-color:  #ed392b;
#             color:  #f1f1f1;
#         }#T_22109_row6_col1{
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }#T_22109_row6_col2{
#             background-color:  #73030f;
#             color:  #f1f1f1;
#         }#T_22109_row7_col2{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_22109_row8_col0{
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }#T_22109_row8_col2{
#             background-color:  #f44d38;
#             color:  #000000;
#         }</style><table id="T_22109_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="3">Gender</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Gender</th>        <th class="col_heading level1 col0" >Female</th>        <th class="col_heading level1 col1" >Male</th>        <th class="col_heading level1 col2" >Non-binary</th>    </tr>    <tr>        <th class="index_name level0" >Employment Status</th>        <th class="index_name level1" >Risk Rating</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22109_level0_row0" class="row_heading level0 row0" rowspan="3">Employed</th>
#                         <th id="T_22109_level1_row0" class="row_heading level1 row0" >High</th>
#                         <td id="T_22109_row0_col0" class="data row0 col0" >56</td>
#                         <td id="T_22109_row0_col1" class="data row0 col1" >69</td>
#                         <td id="T_22109_row0_col2" class="data row0 col2" >77</td>
#             </tr>
#             <tr>
#                                 <th id="T_22109_level1_row1" class="row_heading level1 row1" >Low</th>
#                         <td id="T_22109_row1_col0" class="data row1 col0" >388</td>
#                         <td id="T_22109_row1_col1" class="data row1 col1" >351</td>
#                         <td id="T_22109_row1_col2" class="data row1 col2" >369</td>
#             </tr>
#             <tr>
#                                 <th id="T_22109_level1_row2" class="row_heading level1 row2" >Medium</th>
#                         <td id="T_22109_row2_col0" class="data row2 col0" >195</td>
#                         <td id="T_22109_row2_col1" class="data row2 col1" >207</td>
#                         <td id="T_22109_row2_col2" class="data row2 col2" >198</td>
#             </tr>
#             <tr>
#                         <th id="T_22109_level0_row3" class="row_heading level0 row3" rowspan="3">Self-employed</th>
#                         <th id="T_22109_level1_row3" class="row_heading level1 row3" >High</th>
#                         <td id="T_22109_row3_col0" class="data row3 col0" >67</td>
#                         <td id="T_22109_row3_col1" class="data row3 col1" >55</td>
#                         <td id="T_22109_row3_col2" class="data row3 col2" >56</td>
#             </tr>
#             <tr>
#                                 <th id="T_22109_level1_row4" class="row_heading level1 row4" >Low</th>
#                         <td id="T_22109_row4_col0" class="data row4 col0" >395</td>
#                         <td id="T_22109_row4_col1" class="data row4 col1" >378</td>
#                         <td id="T_22109_row4_col2" class="data row4 col2" >397</td>
#             </tr>
#             <tr>
#                                 <th id="T_22109_level1_row5" class="row_heading level1 row5" >Medium</th>
#                         <td id="T_22109_row5_col0" class="data row5 col0" >204</td>
#                         <td id="T_22109_row5_col1" class="data row5 col1" >178</td>
#                         <td id="T_22109_row5_col2" class="data row5 col2" >182</td>
#             </tr>
#             <tr>
#                         <th id="T_22109_level0_row6" class="row_heading level0 row6" rowspan="3">Unemployed</th>
#                         <th id="T_22109_level1_row6" class="row_heading level1 row6" >High</th>
#                         <td id="T_22109_row6_col0" class="data row6 col0" >55</td>
#                         <td id="T_22109_row6_col1" class="data row6 col1" >64</td>
#                         <td id="T_22109_row6_col2" class="data row6 col2" >64</td>
#             </tr>
#             <tr>
#                                 <th id="T_22109_level1_row7" class="row_heading level1 row7" >Low</th>
#                         <td id="T_22109_row7_col0" class="data row7 col0" >397</td>
#                         <td id="T_22109_row7_col1" class="data row7 col1" >376</td>
#                         <td id="T_22109_row7_col2" class="data row7 col2" >373</td>
#             </tr>
#             <tr>
#                                 <th id="T_22109_level1_row8" class="row_heading level1 row8" >Medium</th>
#                         <td id="T_22109_row8_col0" class="data row8 col0" >191</td>
#                         <td id="T_22109_row8_col1" class="data row8 col1" >174</td>
#                         <td id="T_22109_row8_col2" class="data row8 col2" >200</td>
#             </tr>
#     </tbody></table>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing  import StandardScaler,MinMaxScaler,LabelEncoder
from sklearn.metrics import accuracy_score,classification_report
from sklearn.linear_model import LogisticRegression

# %%
cate=data.select_dtypes(include='object')
cate.head()
# Out:
#         Gender Education Level Marital Status Loan Purpose Employment Status  \
# 0         Male             PhD       Divorced     Business        Unemployed
# 2   Non-binary        Master's         Single         Home          Employed
# 3         Male      Bachelor's         Single     Personal        Unemployed
# 10  Non-binary        Master's         Single         Home          Employed
# 16        Male     High School        Married     Personal        Unemployed
#
#    Payment History              City State        Country Risk Rating
# 0             Poor    Port Elizabeth    AS         Cyprus         Low
# 2             Fair       South Scott    OK     Luxembourg      Medium
# 3        Excellent        Robinhaven    PR         Uganda      Medium
# 10       Excellent    Matthewborough    NH  French Guiana      Medium
# 16       Excellent  Christophermouth    MO          Tonga      Medium

# %%
label=LabelEncoder()
data['Gender']=label.fit_transform(data['Gender'])
data['Education Level']=label.fit_transform(data['Education Level'])
data['Marital Status']=label.fit_transform(data['Marital Status'])
data['Loan Purpose']=label.fit_transform(data['Loan Purpose'])
data['Employment Status']=label.fit_transform(data['Employment Status'])
data['Payment History']=label.fit_transform(data['Payment History'])
data['City']=label.fit_transform(data['City'])
data['State']=label.fit_transform(data['State'])
data['Country']=label.fit_transform(data['Country'])
data['Risk Rating']=label.fit_transform(data['Risk Rating'])

# %%
X=data.drop('Risk Rating',axis=1)
y=data['Risk Rating']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
logist=LogisticRegression()
logist.fit(X_train,y_train)
y_pred=logist.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
print(f'Logisticmodel accuracy_score {accuracy_score(y_test,y_pred)}')
print(classification_report(y_test,y_pred))
# Out:
# Logisticmodel accuracy_score 0.6067179846046186
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       135
#            1       0.61      1.00      0.76       867
#            2       0.00      0.00      0.00       427
#
#     accuracy                           0.61      1429
#    macro avg       0.20      0.33      0.25      1429
# weighted avg       0.37      0.61      0.46      1429

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(splitter='random',criterion='entropy',max_depth=5)
tree.fit(X_train,y_train)
tree_pred=tree.predict(X_test)
print(f'The decisiontree model {accuracy_score(y_test,tree_pred)}')
print(classification_report(y_test,tree_pred))
# Out:
# The decisiontree model 0.6046186144156753
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       135
#            1       0.61      0.99      0.75       867
#            2       0.50      0.01      0.01       427
#
#     accuracy                           0.60      1429
#    macro avg       0.37      0.33      0.26      1429
# weighted avg       0.52      0.60      0.46      1429

# %%
from sklearn.ensemble import RandomForestClassifier
random=RandomForestClassifier(n_estimators=50,criterion='log_loss')
random.fit(X_train,y_train)
random_pred=random.predict(X_test)
print(f'The Randomforest model accuracy score {accuracy_score(y_test,random_pred)}')
print(classification_report(y_test,random_pred))
# Out:
# The Randomforest model accuracy score 0.5906228131560531
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       135
#            1       0.60      0.96      0.74       867
#            2       0.23      0.03      0.05       427
#
#     accuracy                           0.59      1429
#    macro avg       0.28      0.33      0.26      1429
# weighted avg       0.43      0.59      0.46      1429
